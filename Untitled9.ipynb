# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df= pd.read_csv("E:/University/Data Science - Hod/ds/Sheet2.csv")

# %%
path = "E:/University/Data Science - Hod/ds/Sheet2.csv"
df = pd.read_csv(path,na_values = ['na','N/a','Na'])
df.fillna(0,inplace=True)
df.drop_duplicates(inplace=True)
dff = df.T.drop_duplicates().T
df2 = dff.iloc[:,:35].copy()
df3 = df2.iloc[:1469]
# df2 = pd.read_csv("C:/Users/jirti/Downloads/DS/1.csv")
# df2.head(5)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1469 entries, 0 to 1468
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1469 non-null   object
#  1   Attrition                 1469 non-null   object
#  2   BusinessTravel            1469 non-null   object
#  3   DailyRate                 1469 non-null   object
#  4   Department                1469 non-null   object
#  5   DistanceFromHome          1469 non-null   object
#  6   Education                 1469 non-null   object
#  7   EducationField            1469 non-null   object
#  8   EmployeeCount             1469 non-null   object
#  9   EmployeeNumber            1469 non-null   object
#  10  EnvironmentSatisfaction   1469 non-null   object
#  11  Gender                    1469 non-null   object
#  12  HourlyRate                1469 non-null   object
# ...

# %%
df3.describe()
# Out:
#            Age Attrition BusinessTravel  DailyRate              Department  \
# count   1469.0      1469           1469     1469.0                    1469
# unique    43.0         2              3      885.0                       3
# top       35.0        No  Travel_Rarely      691.0  Research & Development
# freq      78.0      1233           1042        6.0                     961
#
#         DistanceFromHome  Education EducationField  EmployeeCount  \
# count             1469.0     1469.0           1469         1469.0
# unique              29.0        5.0              6            1.0
# top                  2.0        3.0  Life Sciences            1.0
# freq               211.0      572.0            605         1469.0
#
#         EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# count           1469.0  ...                    1469.0        1469.0
# unique          1469.0  ...                       5.0           2.0
# ...

# %%
df3.describe(include="O")
# Out:
#            Age Attrition BusinessTravel  DailyRate              Department  \
# count   1469.0      1469           1469     1469.0                    1469
# unique    43.0         2              3      885.0                       3
# top       35.0        No  Travel_Rarely      691.0  Research & Development
# freq      78.0      1233           1042        6.0                     961
#
#         DistanceFromHome  Education EducationField  EmployeeCount  \
# count             1469.0     1469.0           1469         1469.0
# unique              29.0        5.0              6            1.0
# top                  2.0        3.0  Life Sciences            1.0
# freq               211.0      572.0            605         1469.0
#
#         EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# count           1469.0  ...                    1469.0        1469.0
# unique          1469.0  ...                       5.0           2.0
# ...

# %%
sns.countplot(x=df3.Attrition)
plt.show()

# %%
sns.countplot(hue=df3.Attrition,x=df3.BusinessTravel)
plt.show()

# %%
sns.countplot(hue=df3.Attrition,x=df3.Department)
plt.show()

# %%
sns.countplot(x=df3.Attrition,hue=df3.EducationField)
plt.show()

# %%
sns.countplot(x=df3.Attrition,hue=df3.Gender)
plt.show()

# %%
sns.countplot(hue=df3.Attrition,x=df3.OverTime)
plt.show()

# %%
plt.figure(figsize=(10,10), facecolor='white')
sns.countplot(hue=df3.Attrition,x=df3.JobRole)
plt.xlabel('JobRole',fontsize=10)
plt.show()

# %%
numerical_col =[]
for column in df3.columns:
    if df3[column].dtype == "int64" and len(df3[column].unique())>= 10:
        
        numerical_col.append(column)

# %%
numerical_col
# Out:
# []

# %%
data2=df3[['Age',
        'DailyRate',
        'DistanceFromHome',
        'EmployeeNumber',
        'HourlyRate',
        'MonthlyRate',
        'NumCompaniesWorked',
        'PercentSalaryHike',
        'TotalWorkingYears',
        'YearsAtCompany',
        'YearsInCurrentRole',
        'YearsSinceLastPromotion',
        'YearsWithCurrManager']]

# %%
plt.figure(figsize=(20,25),facecolor='white')
plotnumber =1

for column in data2:
    if plotnumber<=16:
        ax= plt.subplot(4,4,plotnumber)
        sns.countplot(x=data2[column].dropna(axis=0)
                     ,hue=df3.Attrition)
        plt.xlabel(column,fontsize=20)
        plt.ylabel('Attrition',fontsize=20)
        plotnumber+=1
        plt.tight_layout()

# %%
sns.histplot(hue=df3.Attrition,x=df3.Age)
plt.show()

# %%
sns.histplot(hue=df3.Attrition,x=df3.DistanceFromHome)
plt.show()

# %%
sns.histplot(x=df3.MonthlyIncome,hue=df3.Attrition)
plt.show()

# %%
sns.histplot(hue=df3.Attrition,x=df3.NumCompaniesWorked)
plt.show()

# %%
sns.histplot(hue=df3.Attrition,x=df3.PercentSalaryHike)
plt.show()

# %%
sns.histplot(x=df3.YearsAtCompany,hue=df3.Attrition)
plt.show()

# %%
discrete_col =[]
for column in df3.columns:
    if df3[column].dtype == "int64" and len(df3[column].unique()) <=10:
        discrete_col.append(column)

# %%
data3=df3[['Education',
          'EmployeeCount',
          'JobInvolvement',
          'JobLevel',
          'JobSatisfaction',
          'NumCompaniesWorked',
          'PerformanceRating',
          'RelationshipSatisfaction',
          'StandardHours',
          'StockOptionLevel',
          'TrainingTimesLastYear',
          'WorkLifeBalance']]

# %%
plt.figure(figsize=(20,25),facecolor='white')
plotnumber =1

for column in data3:
    if plotnumber<=16:
        ax= plt.subplot(4,4,plotnumber)
        sns.countplot(x=data3[column].dropna(axis=0)
                     ,hue=df3.Attrition)
        plt.xlabel(column,fontsize=20)
        plt.ylabel('Attrition',fontsize=20)
        plotnumber+=1
        plt.tight_layout()

# %%
sns.countplot(hue=df3.Attrition,x=df3.EnvironmentSatisfaction)
plt.show()

# %%
sns.histplot(x=df3.JobLevel,hue=df3.Attrition)
plt.show()

# %%
sns.histplot(x=df3.JobInvolvement,hue=df3.Attrition)
plt.show()

# %%
sns.histplot(x=df3.StockOptionLevel,hue=df3.Attrition)
plt.show()

# %%
sns.histplot(x=df3.PerformanceRating,hue=df3.Attrition)
plt.show()
